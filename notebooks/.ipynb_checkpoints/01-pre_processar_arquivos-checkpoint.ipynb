# %% [markdown]
# ## Pré-processamento dos arquivos coletados de métricas
#
# Esse pré-processamento visa gerar um novo arquivo a partir do arquivo original extraído via Prometheus adicionando  novos campos para posterior processamento.
# Os novos campos gerados compreendem um hash de identificação da aplicação além de colunas de tempo (hora e minuto).
#
# ### Métricas coletadas:
# - Consumo de CPU
# - Consumo de Memóroa
# - Pods encerrados por Estouro de memória (OOMKilled)
# - Consumo excessivo de CPU

# %%
import pandas as pd
import hashlib
import glob
import os

# %% [markdown]
# ## Funções gerais

# %%
# Extrai a identificação do sistema a partir do nome do ambiente
def extract_system_name(namespace):
    environment = namespace.split('-')[-1]
    system = namespace.split(f'-{environment}')[0]
    return system

# Cria os diretórios
def create_folder(path):
    try:
       os.makedirs(path)
    except FileExistsError:
       # directory already exists
       pass

def hash(ambiente, pod):
    return hashlib.md5(f'{ambiente}{pod}'.encode('utf-8')).hexdigest()

# %% [markdown]
# ## Pré-processamento de coletas de consumo de cpu

# %%
# Processamento de arquivos de CPU
header_list = ["Sistema", "Ambiente", "Modulo", "Pod", "Uso_CPU"]
path_processados = '/dados/metrics/cpu/processados'
path_projeto = '/home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico'
path_metricas = '/dados/metrics/cpu/'
csv_files = glob.glob(path_projeto+path_metricas+ "*.gz")

# Cria diretorios
create_folder(path_projeto+path_metricas)
create_folder(path_projeto+path_processados)

for file in csv_files:
    print(file)
    data = pd.read_csv(file, sep=';', header=None, names=header_list)
    # obtem horario
    filename = file.replace(path_projeto+path_metricas, "")
    hora = int(filename[4:6])
    min = int(filename[6:8])
        
    # acrescenta coluna de horário    
    data['Hora'] = hora
    
    # acrescenta coluna de minuto    
    data['Minuto'] = min
    
    # acrescenta coluna de hash
    data['Hash'] = [hash(x, y) for x, y in zip(data['Ambiente'], data['Pod'])]
    
    # salva arquivo
    data.to_csv(f'{path_projeto}{path_processados}/error_{hora}_{min}.csv', index=False)
    
print('Fim processamento de CPU')
# Out:
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_00300401112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_06450801112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_11000601112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_01000401112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_21300431102022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_09150701112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_13450701112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_09450801112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_00450501112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_06150701112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_04450701112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_23150631102022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_12000501112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_05000801112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_03000601112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_10001101112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_05150601112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_08451301112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_23450631102022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_23300531102022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_08301201112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_12300401112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_01150501112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_08152601112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_03300601112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_01450601112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_08001401112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_14000601112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_22450731102022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_09001401112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_10301701112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_22150531102022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_05300801112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_00000501112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_11150501112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_11450501112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_10150501112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_02150601112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_06300701112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_07450701112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_13000501112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_11300401112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_07000701112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_05450701112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_00150701112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_09301901112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_21450431102022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_07151001112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_07301101112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_13300401112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_02450801112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_22300631102022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_02300801112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_01300501112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_10450501112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_12150601112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_12450501112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_14150401112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_04000601112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_02000501112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_06000801112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_23000631102022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_04150501112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_04300701112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_22000431102022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_13150501112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_03150701112022.csv.gz
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/cpu/cpu_03450601112022.csv.gz
# Fim processsamento CPU

# %% [markdown]
# ## Pré-processamento de coletas de consumo de Memória

# %%
# Processamento de dados de memória
header_list = ["Sistema", "Ambiente", "Modulo", "Pod", "Uso_Memoria"]
path_processados = '/dados/metrics/memoria/processados'
path_metricas = '/dados/metrics/memoria/'
csv_files = glob.glob(path_projeto+path_metricas+ "*.gz")

# Cria diretorios
create_folder(path_projeto+path_metricas)
create_folder(path_projeto+path_processados)

for file in csv_files:    
    data = pd.read_csv(file, sep=';', header=None, names=header_list)
    # obtem horario
    filename = file.replace(path_projeto+path_metricas, "")
    print(filename)
    hora = int(filename[7:9])
    min = int(filename[9:11])
        
    # acrescenta coluna de horário    
    data['Hora'] = hora
    data['Minuto'] = min
    # acrescenta coluna de hash
    data['Hash'] = [hash(x, y) for x, y in zip(data['Ambiente'], data['Pod'])]
    print(hora, min)
    
    # salva arquivo
    data.to_csv(f'{path_projeto}{path_processados}/memoria_{hora}_{min}.csv', index=False)
    
print('Fim processsamento de Memoria')
# Out:
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_01000401112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_05300901112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_21450431102022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_11150501112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_05150601112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_10150501112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_11450501112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_05000801112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_14150401112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_22450731102022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_09450901112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_10001101112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_04000601112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_06000801112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_08301201112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_00450501112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_11000501112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_12000501112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_01300401112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_03450601112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_04450701112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_23150631102022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_22300631102022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_22000331102022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_05450701112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_11300401112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_12450501112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_06450801112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_08451401112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_08152601112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_13450701112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_21300431102022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_09001301112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_02000501112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_00000501112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_01150501112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_12300401112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_23000631102022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_07301001112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_09302301112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_02300701112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_06150701112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_02450801112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_13300401112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_23450631102022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_03000501112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_06300701112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_07450801112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_22150531102022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_01450601112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_03300601112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_03150601112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_13000501112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_14000601112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_07151101112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_08001401112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_09150801112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_07000701112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_00300401112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_13150401112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_04300601112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_04150401112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_10450501112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_23300531102022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_10301701112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_02150601112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_12150501112022.csv.gz
# 67 40
# /home/56740050368/Treinamento/IA-PUC_Minas/Trabalho_Cientifico/dados/metrics/memoria/memory_00150701112022.csv.gz
# 67 40
# Fim processsamento de Memoria

# %% [markdown]
# ## Pré-processamento das coletas de pods que foram encerrados por erros de memória (OOMKilled)

# %%
# Processamento da coleta de pods encerrados por estouro de memória
header_list = ["Sistema", "Ambiente", "Modulo", "Pod", "Error", "Qtd"]
path_processados = '/dados/metrics/error/processados'
path_metricas = '/dados/metrics/error/'
csv_files = glob.glob(path_projeto+path_metricas+ "*.gz")

# Cria diretorios
create_folder(path_projeto+path_metricas)
create_folder(path_projeto+path_processados)

for file in csv_files:    
    data = pd.read_csv(file, sep=';', header=None, names=header_list)
    # obtem horario
    filename = file.replace(path_projeto+path_metricas, "")
    print(filename)   
    
    hora = int(filename[6:8])
    min = int(filename[8:10])   
        
    # acrescenta coluna de horário    
    data['Hora'] = hora
    data['Minuto'] = min
    # acrescenta coluna de hash
    data['Hash'] = [hash(x, y) for x, y in zip(data['Ambiente'], data['Pod'])]
    
    # salva arquivo
    data.to_csv(f'{path_projeto}{path_processados}/error_{hora}_{min}.csv', index=False)
    
print('Fim processsamento de Erros de Memória')
# Out:
# error_05000601112022.csv.gz
# error_04450701112022.csv.gz
# error_07000601112022.csv.gz
# error_22150431102022.csv.gz
# error_05150601112022.csv.gz
# error_10450501112022.csv.gz
# error_13300301112022.csv.gz
# error_09301701112022.csv.gz
# error_01150501112022.csv.gz
# error_07301001112022.csv.gz
# error_08301101112022.csv.gz
# error_14000501112022.csv.gz
# error_02000501112022.csv.gz
# error_04300601112022.csv.gz
# error_11300301112022.csv.gz
# error_12150401112022.csv.gz
# error_05300801112022.csv.gz
# error_12000401112022.csv.gz
# error_03150601112022.csv.gz
# error_06300601112022.csv.gz
# error_03450601112022.csv.gz
# error_21300331102022.csv.gz
# error_12300301112022.csv.gz
# error_01000401112022.csv.gz
# error_07150801112022.csv.gz
# error_10301501112022.csv.gz
# error_13000501112022.csv.gz
# error_12450501112022.csv.gz
# error_10150401112022.csv.gz
# error_14150301112022.csv.gz
# error_22000331102022.csv.gz
# error_23150531102022.csv.gz
# error_05450601112022.csv.gz
# error_13450601112022.csv.gz
# error_13150401112022.csv.gz
# error_04150401112022.csv.gz
# error_03000501112022.csv.gz
# error_21450431102022.csv.gz
# error_09450701112022.csv.gz
# error_11000401112022.csv.gz
# error_08451301112022.csv.gz
# error_23450531102022.csv.gz
# error_23000531102022.csv.gz
# error_00300401112022.csv.gz
# error_08001201112022.csv.gz
# error_09150601112022.csv.gz
# error_00000401112022.csv.gz
# error_11450401112022.csv.gz
# error_02150601112022.csv.gz
# error_06150701112022.csv.gz
# error_09001101112022.csv.gz
# error_11150301112022.csv.gz
# error_00450401112022.csv.gz
# error_01300401112022.csv.gz
# error_07450601112022.csv.gz
# error_10001001112022.csv.gz
# error_23300531102022.csv.gz
# error_02300701112022.csv.gz
# error_00150601112022.csv.gz
# error_08152401112022.csv.gz
# error_06450701112022.csv.gz
# error_22300531102022.csv.gz
# error_22450631102022.csv.gz
# error_03300501112022.csv.gz
# error_04000501112022.csv.gz
# error_06000701112022.csv.gz
# error_02450701112022.csv.gz
# error_01450601112022.csv.gz
# Fim processsamento de Erros de Memória

# %% [markdown]
# ## Pré-processamento das coletas de pods que excederam o consumo de CPU configurado (throttled)

# %%
# Processamento da coleta de pods encerrados por estouro de memória
header_list = ["Sistema", "Ambiente", "Modulo", "Pod", "Uso_CPU"]
path_processados = '/dados/metrics/throttled/processados'
path_metricas = '/dados/metrics/throttled/'
csv_files = glob.glob(path_projeto+path_metricas+ "*.gz")

# Cria diretorios
create_folder(path_projeto+path_metricas)
create_folder(path_projeto+path_processados)

for file in csv_files:    
    data = pd.read_csv(file, sep=';', header=None, names=header_list)
    # obtem horario
    filename = file.replace(path_projeto+path_metricas, "")
    print(filename)
    hora = int(filename[14:16])
    min = int(filename[16:18])   
        
    # acrescenta coluna de horário    
    data['Hora'] = hora
    data['Minuto'] = min
    # acrescenta coluna de hash
    data['Hash'] = [hash(x, y) for x, y in zip(data['Ambiente'], data['Pod'])]
    
    # salva arquivo
    data.to_csv(f'{path_projeto}{path_processados}/cpu_throttled_{hora}_{min}.csv', index=False)
    
print('Fim processsamento de CPU Throttled')
# Out:
# cpu_throttled_12450601112022.csv.gz
# cpu_throttled_01150601112022.csv.gz
# cpu_throttled_14000601112022.csv.gz
# cpu_throttled_08152601112022.csv.gz
# cpu_throttled_07301101112022.csv.gz
# cpu_throttled_14150401112022.csv.gz
# cpu_throttled_09302301112022.csv.gz
# cpu_throttled_08001401112022.csv.gz
# cpu_throttled_09450901112022.csv.gz
# cpu_throttled_13300401112022.csv.gz
# cpu_throttled_06450801112022.csv.gz
# cpu_throttled_12300401112022.csv.gz
# cpu_throttled_02450801112022.csv.gz
# cpu_throttled_00300401112022.csv.gz
# cpu_throttled_03000601112022.csv.gz
# cpu_throttled_22150531102022.csv.gz
# cpu_throttled_10301701112022.csv.gz
# cpu_throttled_03150601112022.csv.gz
# cpu_throttled_10150401112022.csv.gz
# cpu_throttled_21300431102022.csv.gz
# cpu_throttled_03450601112022.csv.gz
# cpu_throttled_04300701112022.csv.gz
# cpu_throttled_13000401112022.csv.gz
# cpu_throttled_05450701112022.csv.gz
# cpu_throttled_09150701112022.csv.gz
# cpu_throttled_00000501112022.csv.gz
# cpu_throttled_11000601112022.csv.gz
# cpu_throttled_02150601112022.csv.gz
# cpu_throttled_03300501112022.csv.gz
# cpu_throttled_02300701112022.csv.gz
# cpu_throttled_01450601112022.csv.gz
# cpu_throttled_05150701112022.csv.gz
# cpu_throttled_06000701112022.csv.gz
# cpu_throttled_22450631102022.csv.gz
# cpu_throttled_12000501112022.csv.gz
# cpu_throttled_22000431102022.csv.gz
# cpu_throttled_12150601112022.csv.gz
# cpu_throttled_06150701112022.csv.gz
# cpu_throttled_01300401112022.csv.gz
# cpu_throttled_04000601112022.csv.gz
# cpu_throttled_08451401112022.csv.gz
# cpu_throttled_23150531102022.csv.gz
# cpu_throttled_09001301112022.csv.gz
# cpu_throttled_21450431102022.csv.gz
# cpu_throttled_07450701112022.csv.gz
# cpu_throttled_07000601112022.csv.gz
# cpu_throttled_06300601112022.csv.gz
# cpu_throttled_11300401112022.csv.gz
# cpu_throttled_02000501112022.csv.gz
# cpu_throttled_08301301112022.csv.gz
# cpu_throttled_07151001112022.csv.gz
# cpu_throttled_23000631102022.csv.gz
# cpu_throttled_10450401112022.csv.gz
# cpu_throttled_01000401112022.csv.gz
# cpu_throttled_13450701112022.csv.gz
# cpu_throttled_00150701112022.csv.gz
# cpu_throttled_11450401112022.csv.gz
# cpu_throttled_05000701112022.csv.gz
# cpu_throttled_23450531102022.csv.gz
# cpu_throttled_11150401112022.csv.gz
# cpu_throttled_00450501112022.csv.gz
# cpu_throttled_10001001112022.csv.gz
# cpu_throttled_04450701112022.csv.gz
# cpu_throttled_23300531102022.csv.gz
# cpu_throttled_05300801112022.csv.gz
# cpu_throttled_04150401112022.csv.gz
# cpu_throttled_13150501112022.csv.gz
# cpu_throttled_22300631102022.csv.gz
# Fim processsamento de CPU Throttled
